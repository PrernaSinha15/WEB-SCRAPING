# %% [markdown]
# # WEB SCRAPING (Cricbuzz)

# %%
import sys
import time
from bs4 import BeautifulSoup
import requests

# %%
try:
        
    page=requests.get('https://www.cricbuzz.com/')                            
    
except Exception as e:                                   
    error_type, error_obj, error_info = sys.exc_info()      
    print ('ERROR FOR LINK:',url)                          
    print (error_type, 'Line:', error_info.tb_lineno)     
time.sleep(2)   
soup=BeautifulSoup(page.text,'html.parser')
links=soup.find_all('div',attrs={'class':'cb-nws-intr'})

# %%
page
# Out:
# <Response [200]>

# %%
soup
# Out:
# <!DOCTYPE html>
# <html itemscope="" itemtype="http://schema.org/WebPage" lang="en"><head><meta charset="utf-8"/><script>var is_mobile = /symbian|tizen|midp|uc(web|browser)|MSIE (5.0|6.0|7.0|8.0)|tablet/i.test(navigator.userAgent);	if(is_mobile && window.location.hostname != "www1.cricbuzz.com") window.location.hostname = "m.cricbuzz.com";</script><style>html{scroll-behavior: smooth;}	body{background:#E3E6E3; font-family: helvetica,"Segoe UI",Arial,sans-serif;color:#222;font-size:14px; line-height: 1.5; margin:0;}	body, .cb-comm-pg, .cb-hm-mid {min-height:1000px}	.container{width:980px;margin:0 auto;}	.page{max-width: 980px;margin: 0 auto;position: relative;}	.cb-col-8 {width:8%;}	.cb-col-10 {width:10%;}	.cb-col-14 {width:14%;}	.cb-col-16 {width:16%;}	.cb-col-20 {width:20%;}	.cb-col-25 {width:25%;}	.cb-col-27 {width:27%;}	.cb-col-30 {width:30%;}	.cb-col-33 {width:33%;}	.cb-col-40 {width:40%;}	.cb-col-46 {width:46%;}	.cb-col-47 {width:47%;}	.cb-col-50 {width:50%;}	.cb-col-60 {width:60%;}	.cb-col-65 {width:65%;}	.cb-col-66 {width:66%;}	.cb-col-67 {width:67%;}	.cb-col-73 {width:73%;}	.cb-col-75 {width:75%;}	.cb-col-70 {width:70%;}	.cb-col-84 {width:84%;}	.cb-col-80 {width:80%;}	.cb-col-90{width:90%;}	.cb-col-100 {width:100%;}	.cb-col {display: inline-block;box-sizing: border-box;float: left; min-height: 1px;}	h1 {font-size: 36px;line-height: 42px; margin:0;}	h2 {font-size: 24px; margin:0; line-height: 30px;}	h3 {font-size: 18px;line-height: 24px; margin:0; }	h4 {font-size: 16px; margin:0; }	h5 {font-size: 14px; margin: 0;}	.cb-font-18 {font-size:18px;}	img{border-radius: 4px;}	a {text-decoration: none; color:#222;}	a, a:hover, a:active, a:focus {outline: medium none;}	.text-center {text-align: center;}	.cb-nws-lft-col{padding:15px 20px;}	.cb-nws-dtl-lft-col {padding: 10px 30px 0 30px;border-right: 1px solid #ecebeb ;}	.cb-nws-lst-rt{padding-left: 10px;}	.cb-srs-lst-itm {padding: 10px 0;}	.cb-lst-itm-sm{padding:10px 0 5px;}	.cb-scrd-lft-col{padding:15px 10px;} .cb-col-rt{padding: 10px;}	.text-white{color: #fff;}	.cb-text-apple-red{color: #E90B37;}	.cb-color-light-sec{color: #464646;}	.cb-scrd-hdr-rw, .cb-nav-pill-1.active {background: #028062 ;color: #fff;}	.cb-nav{position:relative; height:48px;background: #009270;}	.cb-hm-mnu-itm{padding: 16px 6px 11px; color:#fff; display:inline-block;}	.cb-hm-text{padding:10px 18px 10px 20px;}	.cb-hm-rght{padding: 15px;}	.cb-subnav .cb-sub-navigation {display: none; position: absolute;}	.cb-mat-mnu{background:#4a4a4a; width:980px; font-size: 0;}	.cb-mat-mnu-itm{font-size:12px; color:#fff; padding:10px; cursor: pointer; display:inline-block; max-width: 140px;}	.cb-mat-mnu-ttl{background: #333; padding: 10px 20px;}	.cb-mat-mnu-wrp{margin-bottom: 10px;}	.cb-ovr-flo{overflow: hidden; white-space: nowrap; text-overflow: ellipsis;}	.cb-mat-mnu-all{text-align: center; float: right; width:60px;}	.cb-nav-main{border-bottom:1px solid #e3e6e3;padding:0 0 5px 20px;}	.cb-nav-bar{padding-top:10px;clear:both;}	.cb-lst-itm, .cb-bg-white{background: #fff;}	.cb-nav-tab.active, .cb-nav-tab-hm.active{ font-weight: bold; color: #028062;}	.cb-nav-tab.active {border-bottom: 3px solid #028062; line-height: 24px; }	.cb-nav-tab-hm.active{ border-bottom:2px solid #028062; line-height: 22px;}	.cb-nav-tab{margin-right:20px;padding-bottom:6px;}	.cb-nav-tab-hm{margin-right:15px;padding-bottom:6px;}	.cb-nav-hdr{padding-top:15px}	.cb-nav-subhdr{padding:5px 0 10px 0;}	.cb-lv-scr-mtch-hdr{line-height: 21px;font-size: 16px;}	.disp-none{display:none;}	.disp-blck{display:block;}	.cb-font-24{font-size: 24px;}	.line-ht30{line-height: 30px;}	.line-ht24{line-height: 24px;}	.cb-hm-scg-blk{background: #fff; margin-bottom: 5px; height:90px;}	.mrgn-btm-5{margin-bottom : 5px;}	#scagTabContent .show{display: block; visibility: visible;}	#scagTabContent .hide{display: none; visibility: hidden;}	[ng\:cloak], [ng-cloak], [data-ng-cloak], [x-ng-cloak], .ng-cloak, .x-ng-cloak { display: none !important;}	.cb-hm-lft{margin-bottom:5px;padding:0 15px;}	.cb-hm-lft-hd ...
# .cb-user-itm{position:absolute; top:0; right:5px}</style> </div> </div> <div class="cb-user-itm cb-subnav"> <a href="/premium-subscription/user/account-info" id="cb-plus-user-icon"><span class="cb-plus-ico cb-user-icon"></span></a> <nav class="cb-sub-navigation" id="cb-plus-dropdown" style="right:0px;"> <a class="cb-subnav-item" href="/premium-subscription/user/account-info" target="_self" title="My Account">My Account</a> <a class="cb-subnav-item" ng-click="sign_out_user(false)" target="_self" title="Sign Out">Sign Out</a></nav> </div></nav><style>.cb-text-link{color:#1866db;}
# .cb-plus-menu-button{padding: 8px 14px; background: #fff; border-radius: 18px; border: 0;}
# .cb-plus-menu-button:hover,.cb-plus-menu-button:focus, .cb-plus-menu-button:active{background: #fff;}</style></div></header><div class="page"><div id="fb-root"></div><div class="container" id="page-wrapper" style="display:inline-block;"><div class="ad-unit shosh-embed" id="shosh" style="height:0; width:980px; text-align:center;"></div><span class="ad-unit" id="skin_left" style="overflow:hidden; position:fixed;top:0;left:calc(50% - 635px);margin-right:3px;z-index:-99;"></span><div class="html-refresh" disable-first-load="true" timeout="300000" url="/api/html/matches-menu"><div class="cb-col cb-col-100 mrgn-btm-5"><nav class="cb-mat-mnu" ng-init="direction='up'"><a class="cb-mat-mnu-itm cb-ovr-flo cb-mat-mnu-ttl" href="/cricket-match/live-scores" id="live-scores-link" target="_self" title="">MATCHES</a><a class="cb-mat-mnu-itm cb-ovr-flo" href="/live-cricket-scores/77880/ind-vs-rsa-2nd-odi-india-tour-of-south-africa-2023-24" target="_self" title="India v South Africa, 2nd ODI - Live">IND vs RSA - Live</a><a class="cb-mat-mnu-itm cb-ovr-flo" href="/live-cricket-scores/69785/wi-vs-eng-4th-t20i-england-tour-of-west-indies-2023" target="_self" title="West Indies v England, 4th T20I - Preview">WI vs ENG - Preview</a><a class="cb-mat-mnu-itm cb-ovr-flo" href="/live-cricket-scores/76731/syt-vs-ads-8th-match-big-bash-league-2023-24" target="_self" title="Sydney Thunder v Adelaide Strikers, 8th Match - ADS Won">SYT vs ADS - ADS Won</a><a class="cb-mat-mnu-itm cb-ovr-flo" href="/live-cricket-scores/81475/akl-vs-cntbry-1st-match-super-smash-2023-24" target="_self" title="Auckland v Canterbury, 1st Match - AKL Won">AKL vs CNTBRY - AKL Won</a><a class="cb-mat-mnu-itm cb-ovr-flo" href="/live-cricket-scores/85876/preamc-vs-prewi-1st-match-american-premier-league-2023" target="_self" title="Premium Americans v Premium Windies, 1st Match - Preview">PREAMC vs PREWI - Preview</a><span ng-click="(direction=='up')?direction = 'down' : direction = 'up'"><a class="cb-mat-mnu-itm cb-mat-mnu-all" id="match-dropdown" ng-class="{true:'cb-mat-mnu-cls'}[direction=='down']"><span ng-bind="(direction=='up') ? 'ALL': 'CLOSE'"></span><span ng-class="(direction=='up') ? 'cb-caret-down' : 'cb-caret-up'"></span></a></span></nav><div id="matchmenu"><div class="cb-mm-wrp {{direction}}"><div class="cb-scg-drp-dwn cb-col cb-col-100 cb-mnu-{{direction}}"><nav class="nav cb-mm-nvtb" ng-init="option= 'all'"><a class="cb-nav-pill-2 {{(option=='all')?'active':''}}" ng-click="option='all'" style="margin-right: 20px;">All</a><a class="cb-nav-pill-2 {{(option=='live')?'active':''}}" ng-click="option='live'" style="margin-right: 20px;">Live Now</a><a class="cb-nav-pill-2 {{(option=='today')?'active':''}}" ng-click="option='today'" style="margin-right: 20px;">Today</a></nav><style>.cb-nt-{{option}}{opacity:0.4!important;}</style><ul class="cb-scg-drp-dwn-ul"><li class="cb-lst-mtch cb-lst-dom"><div style="display:inline-block"><div class="cb-mm-typ">INTERNATIONAL</div><div class="cb-scg-srs-nm">South Africa v India, 2023-24</div><div class="cb-mtch-all cb-nt-live cb-nt-today"><a href="/live-cricket-scores/77873/rsa-vs-ind-1st-odi-south-africa-v-india-2023-24" target="_self" title="South Africa v India, 1st ODI - IND Won"><span class="cb-mm-mtch-tm">South Africa vs India</span><span class="cb-mm-liv-tag"></span></a><div class="cb-mm-mtch-nm">1st ODI</div></div></div></li><li class="cb-lst-mtch cb-lst-dom"><div style="display:inline-block"><div class="cb-mtch-all"><a href="/live-cricket-scores/77880/ind-vs-rsa-2nd-odi-south-africa-v-india-2023-24" target="_self" title="India v South Africa, 2nd ODI - Live"><span class="cb-mm-mtch-tm">India vs South Africa</span><span class="cb-mm-liv-tag">  LIVE</span></a><div class="cb-mm-mtch-nm">2nd ODI</div></div></div></li><li class="cb-lst-mtch cb-lst-dom"><div style="display:inline-block"><div class="cb-mtch-all cb-nt-live cb-nt-today"><a href="/live-cricket-scores/77887/rsa-vs-ind-3rd-odi-south-africa-v-india-2023-24" target="_self" title= ...
# }</style> <meta content="400" http-equiv="refresh"/> <div class="cb-col cb-col-20"> <div class="cb-bg-white" id="cb-news-blck"><h2 class="cb-hm-lft-hdr cb-lv-scr-mtch-hdr">LATEST NEWS</h2><div class="cb-hm-lft"><div class="cb-col-100 cb-lst-itm cb-lst-itm-sm"><a class="cb-nws-hdln-ancr text-hvr-underline" href="/cricket-news/128872/know-the-big-earners-shubham-dubey-and-sameer-rizvi" title="Know the big-earners: Shubham Dubey, Sameer Rizvi, Kumar Kushagra">Know the big-earners: Shubham Dubey, Sameer Rizvi, Kumar Kushagra</a><div class="cb-nws-time">1h ago</div></div><div class="cb-col-100 cb-lst-itm cb-lst-itm-sm"><a class="cb-nws-hdln-ancr text-hvr-underline" href="/cricket-news/128870/cant-expect-soumya-to-fill-shakibs-shoes-hathurusingha" title="Can't expect Soumya to fill Shakib's shoes - Hathurusingha">Can't expect Soumya to fill Shakib's shoes - Hathurusingha</a><div class="cb-nws-time">5h ago</div></div><div class="cb-col-100 cb-lst-itm cb-lst-itm-sm"><a class="cb-nws-hdln-ancr text-hvr-underline" href="/cricket-news/128869/felt-like-i-couldnt-face-people-rishabh-pant" title="Felt like I couldn't face people: Rishabh Pant">Felt like I couldn't face people: Rishabh Pant</a><div class="cb-nws-time">5h ago</div></div><div class="cb-col-100 cb-lst-itm cb-lst-itm-sm"><a class="cb-nws-hdln-ancr text-hvr-underline" href="/cricket-news/128868/mumbai-indians-refute-rumours-of-trade-on-rohit-and-others" title="Mumbai Indians refute rumours of trade on Rohit and others">Mumbai Indians refute rumours of trade on Rohit and others</a><div class="cb-nws-time">5h ago</div></div><div class="cb-col-100 cb-lst-itm cb-lst-itm-sm"><a class="cb-nws-hdln-ancr text-hvr-underline" href="/cricket-news/128866/hetmyer-dropped-for-last-two-england-t20is" title="Hetmyer dropped for last-two England T20Is">Hetmyer dropped for last-two England T20Is</a><div class="cb-nws-time">10h ago</div></div><div class="cb-col-100 cb-lst-itm cb-lst-itm-sm"><a class="cb-nws-hdln-ancr text-hvr-underline" href="/cricket-news/128864/rishabh-pant-all-set-to-attend-ipl-auction-in-dubai" title="Rishabh Pant all set to attend IPL Auction in Dubai">Rishabh Pant all set to attend IPL Auction in Dubai</a><div class="cb-nws-time">19h ago</div></div><div class="cb-col-100 cb-lst-itm cb-lst-itm-sm"><a class="cb-nws-hdln-ancr text-hvr-underline" href="/cricket-news/128863/u19-asia-cup-title-bangladesh-players-credit-india-tour-for-success" title="U19 Asia Cup title - Bangladesh players credit India tour for success">U19 Asia Cup title - Bangladesh players credit India tour for success</a><div class="cb-nws-time">21h ago</div></div><div class="cb-col-100 cb-lst-itm cb-lst-itm-sm"><a class="cb-nws-hdln-ancr text-hvr-underline" href="/cricket-news/128862/ipl-2024-sa-wi-and-nz-confirm-full-participation-limited-availability-of-english-players" title="IPL 2024: SA, WI and NZ confirm full participation; limited availability of English players">IPL 2024: SA, WI and NZ confirm full participation; limited availability of English players</a><div class="cb-nws-time">1d ago</div></div><div class="cb-col-100 cb-lst-itm cb-lst-itm-sm"><a class="cb-nws-hdln-ancr text-hvr-underline" href="/cricket-news/128861/ilt20-bans-naveen-ul-haq-for-20-months" title="ILT20 bans Naveen-ul-Haq for 20 months">ILT20 bans Naveen-ul-Haq for 20 months</a><div class="cb-nws-time">1d ago</div></div><div class="cb-col-100 cb-lst-itm cb-lst-itm-sm"><a class="cb-nws-hdln-ancr text-hvr-underline" href="/cricket-news/128858/mitchell-starc-in-focus-in-a-more-equitable-auction" title="Mitchell Starc in focus in a more equitable IPL auction">Mitchell Starc in focus in a more equitable IPL auction</a><div class="cb-nws-time">1d ago</div></div><div class="cb-hm-mr-lnk"><a class="cb-font-12 cb-text-link" href="/cricket-news/latest-news" title="More News"><i>More News..</i></a></div></div></div> <div class="cb-bg-white" id="hm-photos-blk"> <h2 class="cb-hm-lft-hdr cb-lv-scr-mtch-hdr">LATEST PHOTOS</h2> <div class="cb-hm-lft">  ...
# });</script> <div class="cb-col cb-hm-mid cb-bg-white cb-hmpage" style="clear:both"> <div class="big-crd-main cb-bg-white cb-pos-rel"><div class="crd-cntxt"><span>IPL 2024 AUCTION</span></div><a href="/cricket-news/128871/kkr-sign-mitchell-starc-for-an-ipl-record-inr-2475-crores" title="KKR sign Mitchell Starc for an IPL record INR 24.75 crores"><img alt="KKR sign Mitchell Starc for an IPL record INR 24.75 crores" height="235" itemprop="image" src="https://static.cricbuzz.com/a/img/v1/420x235/i1/c366453/kkr-sign-mitchell-starc-for-an.jpg" title="KKR sign Mitchell Starc for an IPL record INR 24.75 crores" width="420"/></a><h2 class="big-crd-hdln"><a href="/cricket-news/128871/kkr-sign-mitchell-starc-for-an-ipl-record-inr-2475-crores" title="KKR sign Mitchell Starc for an IPL record INR 24.75 crores">	KKR sign Mitchell Starc for an IPL record INR 24.75 crores</a></h2><div class="cb-nws-intr">Australia's left-arm fast bowler last played the IPL in 2015 but comfortably passed the INR 20.50 Cr that SRH paid for Pat Cummins</div><div class="big-crd-reltd-itm"><a class="big-crd-rltd-txt" href="/cricket-news/128859/ipl-auction-big-payday-for-the-pacers" title="IPL Auction - Big payday for the pacers"><span class="cb-pretag">Live Blog / </span>IPL Auction - Big payday for the pacers</a></div><div class="big-crd-reltd-itm"><a class="big-crd-rltd-txt" href="/cricket-news/128867/ipl-2024-current-squads-and-purse-remaining" title="IPL 2024 - Current squads and purse remaining">IPL 2024 - Current squads and purse remaining</a></div><div class="big-crd-reltd-itm"><a class="big-crd-rltd-txt" href="/cricket-news/128869/felt-like-i-couldnt-face-people-rishabh-pant" title="Felt like I couldn't face people: Rishabh Pant">Felt like I couldn't face people: Rishabh Pant</a></div></div><div class="big-crd-main cb-bg-white cb-pos-rel"><div class="crd-cntxt"><span>IPL 2024 - MUMBAI INDIANS</span></div><a href="/cricket-news/128868/mumbai-indians-refute-rumours-of-trade-on-rohit-and-others" title="Mumbai Indians refute rumours of trade on Rohit and others"><img alt="Mumbai Indians refute rumours of trade on Rohit and others" height="235" itemprop="image" src="https://static.cricbuzz.com/a/img/v1/420x235/i1/c366354/mumbai-indians-refute-rumours.jpg" title="Mumbai Indians refute rumours of trade on Rohit and others" width="420"/></a><h2 class="big-crd-hdln"><a href="/cricket-news/128868/mumbai-indians-refute-rumours-of-trade-on-rohit-and-others" title="Mumbai Indians refute rumours of trade on Rohit and others">	Mumbai Indians refute rumours of trade on Rohit and others</a></h2><div class="cb-nws-intr">There have been speculations of unhappiness in the camp following the appointment of Hardik as captain</div><div class="big-crd-reltd-itm"><a class="big-crd-rltd-txt" href="/cricket-news/128850/india-appearances-for-uncapped-players-to-be-incentivized" title="India appearances for uncapped players to be incentivized">India appearances for uncapped players to be incentivized</a></div><div class="big-crd-reltd-itm"><a class="big-crd-rltd-txt" href="/cricket-news/128827/bcci-to-course-correct-after-sakariya-suspect-action-error" title="BCCI to course correct after Sakariya suspect action error">BCCI to course correct after Sakariya suspect action error</a></div><div class="big-crd-reltd-itm"><a class="big-crd-rltd-txt" href="/cricket-news/128862/sa-wi-and-nz-confirm-full-participation-limited-availability-of-english-players" title="SA, WI and NZ confirm full participation; limited availability of English players">SA, WI and NZ confirm full participation; limited availability of English players</a></div></div><div class="big-crd-main cb-bg-white cb-pos-rel"><div class="crd-cntxt"><span>RSA VS IND, 2ND ODI</span></div><a href="/live-cricket-scores/77880/rsa-vs-ind-2nd-odi" title="South Africa chip away with regular strikes"><img alt="South Africa chip away with regular strikes" height="235" itemprop="image" src="https://static.cricbuzz.com/a/img/v1/420x235/i1/c3 ...

# %%
links
# Out:
# [<div class="cb-nws-intr">Australia's left-arm fast bowler last played the IPL in 2015 but comfortably passed the INR 20.50 Cr that SRH paid for Pat Cummins</div>,
#  <div class="cb-nws-intr">There have been speculations of unhappiness in the camp following the appointment of Hardik as captain</div>,
#  <div class="cb-nws-intr">Sai Sudharsan and KL Rahul got fifties but couldn't kick on to bigger scores</div>,
#  <div class="cb-nws-intr">KS Bharath has been roped in as his replacement for the upcoming Test series against South Africa</div>,
#  <div class="cb-nws-intr">If Pat Cummins captures your imagination then Nathan Lyon intrigues it. You want more of Cummins, while you want to know more about Lyon</div>,
#  <div class="cb-nws-intr">Bangladesh are struggling to fill the gaping hole created by the injury to Shakib al Hasan</div>,
#  <div class="cb-nws-intr">Sri Lanka's performances on the world stage have grown increasingly limp over the past decade, but ongoing changes offer optimism</div>,
#  <div class="cb-nws-intr">The story of how Mumbai Indians went about the captaincy transition in their ranks</div>,
#  <div class="cb-nws-intr">The pacer was charged for a breach of contract with Sharjah Warriors</div>,
#  <div class="cb-nws-intr">The match bowling tally might only read 4 for 62 but her ability to find ways to contribute in all three facets of the game underscored her value to the side once again</div>,
#  <div class="cb-nws-intr">Oshane Thomas replaces Alzarri Joseph, who has been rested ahead of next month's all-formats tour of Australia </div>,
#  <div class="cb-nws-intr">The left-hander, who scored 91 runs in Bangladesh's maiden ODI win over South Africa overseas, has evolved from a one-dimensional player strong on the off-side</div>,
#  <div class="cb-nws-intr">All the updates and reports from the three T20I, three ODI series between the hosts New Zealand and Pakistan</div>,
#  <div class="cb-nws-intr">All the updates and reports from the three T20I, three ODI series between Ireland and the hosts Zimbabwe</div>,
#  <div class="cb-nws-intr">Menaria was a part of the victorious side against a side he represented for fourteen years </div>,
#  <div class="cb-nws-intr">The second season of USA's marquee T20 league will begin four days after the conclusion of the T20 World Cup</div>,
#  <div class="cb-nws-intr">The duo's sparkling openings stand laid the foundation for a challenging run chase</div>,
#  <div class="cb-nws-intr">News bytes that you may have otherwise missed</div>,
#  <div class="cb-nws-intr">That India are in South Africa so soon after being denied what until the World Cup final seemed a prize they had a divine right to claim adds a layer to a narrative that isn't short on context</div>,
#  <div class="cb-nws-intr">Virat Kohli surpassed his idol Sachin Tendulkar's record of most ODI hundreds at the home of Indian cricket, en route to putting India into yet another World Cup final</div>,
#  <div class="cb-nws-intr">The man who fell off a golf cart and got concussed a week before had left everyone else feeling silly, disillusioned and overwhelmed, even as he soared to enter the pantheon of the greats with an innings of a lifetime</div>,
#  <div class="cb-nws-intr">Rohit Sharma's high-risk game has allowed Virat Kohli to be unapologetically Virat Kohli</div>,
#  <div class="cb-nws-intr">India's national capital that is home to a strong Afghan sub-culture faces an uncertain future</div>,
#  <div class="cb-nws-intr">The New Zealand quick tells Cricbuzz how undergoing surgery early in his career, and carrying a lot of drinks, taught him how to choose his internal narrative</div>,
#  <div class="cb-nws-intr">For all the qualities associated with Rohit - the quirky and laid back persona, his easy predisposition - there is a common thread of loyalty and friendship</div>,
#  <div class="cb-nws-intr">South Africa's latest fast bowling find is young, quick, talented and has impeccable manners. How did he become not only a hot prospect, but also so thoroughly decent?</div>]

# %%
for i in links:
    print(i.text)
    print("\n")
# Out:
# Australia's left-arm fast bowler last played the IPL in 2015 but comfortably passed the INR 20.50 Cr that SRH paid for Pat Cummins
#
#
# There have been speculations of unhappiness in the camp following the appointment of Hardik as captain
#
#
# Sai Sudharsan and KL Rahul got fifties but couldn't kick on to bigger scores
#
#
# KS Bharath has been roped in as his replacement for the upcoming Test series against South Africa
#
#
# If Pat Cummins captures your imagination then Nathan Lyon intrigues it. You want more of Cummins, while you want to know more about Lyon
#
#
# Bangladesh are struggling to fill the gaping hole created by the injury to Shakib al Hasan
#
#
# Sri Lanka's performances on the world stage have grown increasingly limp over the past decade, but ongoing changes offer optimism
#
#
# The story of how Mumbai Indians went about the captaincy transition in their ranks
#
#
# The pacer was charged for a breach of contract with Sharjah Warriors
#
#
# The match bowling tally might only read 4 for 62 but her ability to find ways to contribute in all three facets of the game underscored her value to the side once again
#
#
# Oshane Thomas replaces Alzarri Joseph, who has been rested ahead of next month's all-formats tour of Australia
#
#
# The left-hander, who scored 91 runs in Bangladesh's maiden ODI win over South Africa overseas, has evolved from a one-dimensional player strong on the off-side
#
#
# All the updates and reports from the three T20I, three ODI series between the hosts New Zealand and Pakistan
#
#
# All the updates and reports from the three T20I, three ODI series between Ireland and the hosts Zimbabwe
#
#
# Menaria was a part of the victorious side against a side he represented for fourteen years
#
#
# The second season of USA's marquee T20 league will begin four days after the conclusion of the T20 World Cup
#
#
# The duo's sparkling openings stand laid the foundation for a challenging run chase
#
#
# News bytes that you may have otherwise missed
#
#
# That India are in South Africa so soon after being denied what until the World Cup final seemed a prize they had a divine right to claim adds a layer to a narrative that isn't short on context
#
#
# Virat Kohli surpassed his idol Sachin Tendulkar's record of most ODI hundreds at the home of Indian cricket, en route to putting India into yet another World Cup final
#
#
# The man who fell off a golf cart and got concussed a week before had left everyone else feeling silly, disillusioned and overwhelmed, even as he soared to enter the pantheon of the greats with an innings of a lifetime
#
#
# Rohit Sharma's high-risk game has allowed Virat Kohli to be unapologetically Virat Kohli
#
#
# India's national capital that is home to a strong Afghan sub-culture faces an uncertain future
#
#
# The New Zealand quick tells Cricbuzz how undergoing surgery early in his career, and carrying a lot of drinks, taught him how to choose his internal narrative
#
#
# For all the qualities associated with Rohit - the quirky and laid back persona, his easy predisposition - there is a common thread of loyalty and friendship
#
#
# South Africa's latest fast bowling find is young, quick, talented and has impeccable manners. How did he become not only a hot prospect, but also so thoroughly decent?
